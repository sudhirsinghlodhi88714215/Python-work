# %%
import requests 
from  bs4 import BeautifulSoup 
from urllib.request import urlopen as uReq
import logging
##import pymongo
import os

# %%
save_dir = 'images/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {'User-Agente':"Mozella/5.0(Windows NT 10.0;Win64; x64)AppleWebKIt/537.36(KHML,like Gecko)Chrome/58.0.3029.110 Safari/537.36"}

# %%
query = 'Ganesg'
response=requests.get(f"https://www.google.com/search?rlz=1C1CHBF_enIN1046IN1046&sxsrf=APwXEdeb1vBc5jIA9Qu8RtZ4D1h4ogJ_LA:1681578099667&q=mahadev+images&tbm=isch&chips=q:mahadev+photo,g_1:wallpaper:Mo2ohGQp0bM%3D&usg=AI4_-kSGdtlMfmbU5Gc4d_V4SBmjcll7FA&sa=X&ved=2ahUKEwifr6vKrqz-AhUMpVYBHZ_EBmYQgIoDKAB6BAgZEBE&biw=1536&bih=714&dpr=1.25")

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en-IN"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>mahadev images - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;min-width:240px;}.FbhRzb{border-left:thin solid #dadce0;border-right:thin solid #dadce0;border-top:thin solid #dadce0;height:40px;overflow:hidden}.n692Zd{margin-bottom:10px}.cvifge{height:40px;border-spacing:0}.QvGUP{height:40px;padding:0 8px 0 8px;vertical-align:top}.O4cRJf{height:40px;width:100%;padding:0;padding-right:16px}.O1ePr{height:40px;padding:0;vertical-align:top}.kgJEQe{height:36px;width:98px;vertical-align:top;margin-top:4px}.lXLRf{vertical-align:top}.MhzMZd{border:
# ...

# %%
BeautifulSoup(response.content,'html.parser')
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup.find_all('img')
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQupGvAB--7JPDN1w8pRbY3PKX3JzAFx7zkdqGEZ9etgmq86ufgYBtbxM7dCA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZYd8UR9C_cO2sKnsqAwr7OJ9cw7IB5ihvGgDgHOKpk3o9zYTYc28M-F4peZU&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgFNQ96donvGAsZFgdzRB7ZiB4hx9-klW7wMhpPrXpmN5qZf1F7T77qt4Hxrw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRc_IIynEYCNu9LXvlE1eETeKuVC3KSZAgAmlNooDNsW169c5ODf9EjLEW1sw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrOeSWqZ1ub5ZZ9kM5n0Aq8TkJo0h7xbZoZjNzKJ2QQaifBLVoGOw8vppGy-o&amp;s"/>,
# ...

# %%
image_tages = soup.find_all('img')

# %%
image_tages
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQupGvAB--7JPDN1w8pRbY3PKX3JzAFx7zkdqGEZ9etgmq86ufgYBtbxM7dCA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZYd8UR9C_cO2sKnsqAwr7OJ9cw7IB5ihvGgDgHOKpk3o9zYTYc28M-F4peZU&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgFNQ96donvGAsZFgdzRB7ZiB4hx9-klW7wMhpPrXpmN5qZf1F7T77qt4Hxrw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRc_IIynEYCNu9LXvlE1eETeKuVC3KSZAgAmlNooDNsW169c5ODf9EjLEW1sw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrOeSWqZ1ub5ZZ9kM5n0Aq8TkJo0h7xbZoZjNzKJ2QQaifBLVoGOw8vppGy-o&amp;s"/>,
# ...

# %%
len(image_tages )
# Out:
# 21

# %%
del image_tages [0]

# %%
image_tages
# Out:
# [<img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQupGvAB--7JPDN1w8pRbY3PKX3JzAFx7zkdqGEZ9etgmq86ufgYBtbxM7dCA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZYd8UR9C_cO2sKnsqAwr7OJ9cw7IB5ihvGgDgHOKpk3o9zYTYc28M-F4peZU&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgFNQ96donvGAsZFgdzRB7ZiB4hx9-klW7wMhpPrXpmN5qZf1F7T77qt4Hxrw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRc_IIynEYCNu9LXvlE1eETeKuVC3KSZAgAmlNooDNsW169c5ODf9EjLEW1sw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrOeSWqZ1ub5ZZ9kM5n0Aq8TkJo0h7xbZoZjNzKJ2QQaifBLVoGOw8vppGy-o&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4HdNnVkSGZBAYDg8oxReacVX9F0pkq09bGXEq_n_hJQvTvPYZkWNhkp3Meaw&amp;s"/>,
# ...

# %%
img_data_mongo=[]
for i in image_tages :
    image_url=i['src']
    image_data= requests.get(image_url).content
    mydict= {'index':image_url  ,'image':image_data}
    img_data_mongo.append(mydict)
    with open (os.path.join(save_dir,f'{query}_{image_tages .index(i)}.jpg'),'wb') as f :
               f.write(image_data)
#client = pymongo.MongoClient("mongodb+srv://sudhir:Sudhir887142@cluster0.jvlbndq.mongodb.net/?retryWrites=true&w=majority")
#db = client['image_scrap']
#coll_imagedb['image_scrap'] 
#coll_image.insert_many(img_data_mongo)
