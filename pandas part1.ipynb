# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 pd.read_csv("data11.csv")
# Out:
#      name  gmail  phon_number cource
# 0       s  s@sgd          123     mn
# 1       a  s@sgd          123     mn
# 2       b  s@sgd          123     mn
# 3       c  s@sgd          123     mn
# 4       d  s@sgd          123     mn
# ..    ...    ...          ...    ...
# 154   rts  s@sgd          123     mn
# 155  rtya  s@sgd          123     mn
# 156  tyab  s@sgd          123     mn
# 157     c  s@sgd          123     mn
# 158  adgd  s@sgd          123     mn
#
# [159 rows x 4 columns]

# %%
df = pd.read_csv("data11.csv")

# %%
df.head(11)
# Out:
#    name  gmail  phon_number cource
# 0     s  s@sgd          123     mn
# 1     a  s@sgd          123     mn
# 2     b  s@sgd          123     mn
# 3     c  s@sgd          123     mn
# 4     d  s@sgd          123     mn
# 5     e  s@sgd          123     mn
# 6     f  s@sgd          123     mn
# 7    bh  s@sgd          123     mn
# 8     c  s@sgd          123     mn
# 9    dx  s@sgd          123     mn
# 10   xs  s@sgd           22     mn

# %%
df.tail()
# Out:
#      name  gmail  phon_number cource
# 154   rts  s@sgd          123     mn
# 155  rtya  s@sgd          123     mn
# 156  tyab  s@sgd          123     mn
# 157     c  s@sgd          123     mn
# 158  adgd  s@sgd          123     mn

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
(df.columns)
# Out:
# Index(['name', 'gmail', 'phon_number', 'cource'], dtype='object')

# %%
list(df.columns)
# Out:
# ['name', 'gmail', 'phon_number', 'cource']

# %%
df['name']
# Out:
# 0         s
# 1         a
# 2         b
# 3         c
# 4         d
#        ...
# 154     rts
# 155    rtya
# 156    tyab
# 157       c
# 158    adgd
# Name: name, Length: 159, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df['gmail']
# Out:
# 0      s@sgd
# 1      s@sgd
# 2      s@sgd
# 3      s@sgd
# 4      s@sgd
#        ...
# 154    s@sgd
# 155    s@sgd
# 156    s@sgd
# 157    s@sgd
# 158    s@sgd
# Name: gmail, Length: 159, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'gmail', 'phon_number', 'cource'], dtype='object')

# %%
df[['gmail','cource', 'name']]
# Out:
#      gmail cource  name
# 0    s@sgd     mn     s
# 1    s@sgd     mn     a
# 2    s@sgd     mn     b
# 3    s@sgd     mn     c
# 4    s@sgd     mn     d
# ..     ...    ...   ...
# 154  s@sgd     mn   rts
# 155  s@sgd     mn  rtya
# 156  s@sgd     mn  tyab
# 157  s@sgd     mn     c
# 158  s@sgd     mn  adgd
#
# [159 rows x 3 columns]

# %%
df.dtypes
# Out:
# name           object
# gmail          object
# phon_number     int64
# cource         object
# dtype: object

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml 
import pandas as pd
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 =url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3[['Age','Player']]
# Out:
#     Age          Player
# 0    24      Quincy Acy
# 1    20    Jordan Adams
# 2    21    Steven Adams
# 3    28     Jeff Adrien
# 4    29   Arron Afflalo
# ..   ..             ...
# 670  26  Thaddeus Young
# 671  26  Thaddeus Young
# 672  26  Thaddeus Young
# 673  22     Cody Zeller
# 674  25    Tyler Zeller
#
# [675 rows x 2 columns]

# %%
df3.to_csv('players_data.csv')

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2017_totals.html')
# Out:
# [      Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  \
#  0      1       Álex Abrines  SG  23  OKC  68   6  1055  134  341  ...  .898
#  1      2         Quincy Acy  PF  26  TOT  38   1   558   70  170  ...  .750
#  2      2         Quincy Acy  PF  26  DAL   6   0    48    5   17  ...  .667
#  3      2         Quincy Acy  PF  26  BRK  32   1   510   65  153  ...  .754
#  4      3       Steven Adams   C  23  OKC  80  80  2389  374  655  ...  .611
#  ..   ...                ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...
#  614  482        Cody Zeller   C  24  CHO  62  58  1725  253  443  ...  .679
#  615  483       Tyler Zeller   C  27  BOS  51   5   525   78  158  ...  .564
#  616  484  Stephen Zimmerman   C  20  ORL  19   0   108   10   31  ...  .600
#  617  485        Paul Zipser  SF  22  CHI  44  18   843   88  221  ...  .775
#  618  486        Ivica Zubac   C  19  LAL  38  11   609  126  238  ...  .653
#
# ...

# %%
f =pd.read_html('https://www.basketball-reference.com/leagues/NBA_2017_totals.html')

# %%
type(f)
# Out:
# list

# %%
len(f)
# Out:
# 1

# %%
f[0]
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  \
# 0      1       Álex Abrines  SG  23  OKC  68   6  1055  134  341  ...  .898
# 1      2         Quincy Acy  PF  26  TOT  38   1   558   70  170  ...  .750
# 2      2         Quincy Acy  PF  26  DAL   6   0    48    5   17  ...  .667
# 3      2         Quincy Acy  PF  26  BRK  32   1   510   65  153  ...  .754
# 4      3       Steven Adams   C  23  OKC  80  80  2389  374  655  ...  .611
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...
# 614  482        Cody Zeller   C  24  CHO  62  58  1725  253  443  ...  .679
# 615  483       Tyler Zeller   C  27  BOS  51   5   525   78  158  ...  .564
# 616  484  Stephen Zimmerman   C  20  ORL  19   0   108   10   31  ...  .600
# 617  485        Paul Zipser  SF  22  CHI  44  18   843   88  221  ...  .775
# 618  486        Ivica Zubac   C  19  LAL  38  11   609  126  238  ...  .653
#
#      ORB  DRB  TRB AST STL BLK  TOV   PF  PTS
# ...

# %%
f1= f[0]

# %%
f1
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  \
# 0      1       Álex Abrines  SG  23  OKC  68   6  1055  134  341  ...  .898
# 1      2         Quincy Acy  PF  26  TOT  38   1   558   70  170  ...  .750
# 2      2         Quincy Acy  PF  26  DAL   6   0    48    5   17  ...  .667
# 3      2         Quincy Acy  PF  26  BRK  32   1   510   65  153  ...  .754
# 4      3       Steven Adams   C  23  OKC  80  80  2389  374  655  ...  .611
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...
# 614  482        Cody Zeller   C  24  CHO  62  58  1725  253  443  ...  .679
# 615  483       Tyler Zeller   C  27  BOS  51   5   525   78  158  ...  .564
# 616  484  Stephen Zimmerman   C  20  ORL  19   0   108   10   31  ...  .600
# 617  485        Paul Zipser  SF  22  CHI  44  18   843   88  221  ...  .775
# 618  486        Ivica Zubac   C  19  LAL  38  11   609  126  238  ...  .653
#
#      ORB  DRB  TRB AST STL BLK  TOV   PF  PTS
# ...

# %%
f1.head()
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  23  OKC  68   6  1055  134  341  ...  .898   18   68
# 1  2    Quincy Acy  PF  26  TOT  38   1   558   70  170  ...  .750   20   95
# 2  2    Quincy Acy  PF  26  DAL   6   0    48    5   17  ...  .667    2    6
# 3  2    Quincy Acy  PF  26  BRK  32   1   510   65  153  ...  .754   18   89
# 4  3  Steven Adams   C  23  OKC  80  80  2389  374  655  ...  .611  281  332
#
#    TRB AST STL BLK  TOV   PF  PTS
# 0   86  40  37   8   33  114  406
# 1  115  18  14  15   21   67  222
# 2    8   0   0   0    2    9   13
# 3  107  18  14  15   19   58  209
# 4  613  86  89  78  146  195  905
#
# [5 rows x 30 columns]

# %%
f1.tail()
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  \
# 614  482        Cody Zeller   C  24  CHO  62  58  1725  253  443  ...  .679
# 615  483       Tyler Zeller   C  27  BOS  51   5   525   78  158  ...  .564
# 616  484  Stephen Zimmerman   C  20  ORL  19   0   108   10   31  ...  .600
# 617  485        Paul Zipser  SF  22  CHI  44  18   843   88  221  ...  .775
# 618  486        Ivica Zubac   C  19  LAL  38  11   609  126  238  ...  .653
#
#      ORB  DRB  TRB AST STL BLK TOV   PF  PTS
# 614  135  270  405  99  62  58  65  189  639
# 615   43   81  124  42   7  21  20   61  178
# 616   11   24   35   4   2   5   3   17   23
# 617   15  110  125  36  15  16  40   78  240
# 618   41  118  159  30  14  33  30   66  284
#
# [5 rows x 30 columns]

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2022_totals.html')
# Out:
# [      Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
#  1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
#  2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
#  3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
#  4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
#  ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
#  838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
#  839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
#  840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
#  841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...

# %%
d = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2022_totals.html')

# %%
d
# Out:
# [      Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
#  1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
#  2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
#  3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
#  4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
#  ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
#  838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
#  839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
#  840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
#  841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...

# %%
len(d)
# Out:
# 1

# %%
d[0]
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...

# %%
vv = d[0]

# %%
vv
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...

# %%
vv.head()
# Out:
#   Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1   Precious Achiuwa   C  22  TOR  73  28  1725  265  603  ...  .595  146
# 1  2       Steven Adams   C  28  MEM  76  75  1999  210  384  ...  .543  349
# 2  3        Bam Adebayo   C  24  MIA  56  56  1825  406  729  ...  .753  137
# 3  4       Santi Aldama  PF  21  MEM  32   0   360   53  132  ...  .625   33
# 4  5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  458  ...  .873   73
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  327  473   82  37  41   84  151   664
# 1  411  760  256  65  60  115  153   528
# 2  427  564  190  80  44  148  171  1068
# 3   54   87   21   6  10   16   36   132
# 4  185  258   42  14  47   44   78   607
#
# [5 rows x 30 columns]

# %%
vv.to_csv('plear.csv')

# %%
import pandas as pd
    
pd.read_csv("da.csv")
# Out:
#    Id       name  Age  Gender
# 0   4      Alice   25  Female
# 1   8        Bob   30    Male
# 2  15     Claire   27  Female
# 3  16       sudh   24    male
# 4  23      rohri   21    male
# 5  42     sartaj   22    male
# 6  30      shivs   23    male
# 7  45  raghunath   40    male
# 8  56     Ahilya   39  Female
# 9  60       bhai   20    male
