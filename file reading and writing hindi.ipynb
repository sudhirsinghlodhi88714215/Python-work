# %%
data = {
       'name':'sudhir',
        'mail':'sudhirsinghlodhi@',
         'phon':87706777,
          'subject':'data science',
           
}

# %%
import json

# %%
with open('data.json','w') as f :
    json.dump(data,f)

# %%
with open('data.json','r') as f:
     data2=json.load(f)

# %%
data2
# Out:
# {'name': 'sudhir',
#  'mail': 'sudhirsinghlodhi@',
#  'phon': 87706777,
#  'subject': 'data science'}

# %%
data2['name']
# Out:
# 'sudhir'

# %%
import csv

# %%
data = [['name','gmail','phon_number','cource'],
        ['s','s@sgd',123,'mn'],
          ['a','s@sgd',123,'mn'],
          ['b','s@sgd',123,'mn'],
          ['c','s@sgd',123,'mn'],
          ['d','s@sgd',123,'mn'],
          ['e','s@sgd',123,'mn'],
          ['f','s@sgd',123,'mn'],
          ['bh','s@sgd',123,'mn'],
          ['c','s@sgd',123,'mn'],
          ['dx','s@sgd',123,'mn'],
          ['xs','s@sgd',22,'mn'],
          ['a d','s@sgd',123,'mn'],
          ['bd','s@sgd',123,'mn'],
          ['cc','s@sgd',123,'mn'],
          ['dd ','s@sgd',123,'mn'],
          ['sf','s@sgd',123,'mn'],
          ['fva','s@sgd',123,'mn'],
          ['bf','s@sgd',123,'mn'],
          ['cf','s@sgd',123,'mn'],
          ['fbd','s@sgd',123,'mn'],
          ['sfb','s@sgd',123,'mn'],
          ['fa','s@sgd',123,'mn'],
          ['fb','s@sgd',123,'mn'],
          ['cab','s@sgd',123,'mn'],
          ['fd','s@sgd',123,'mn'],
          ['ffs','s@sgd',123,'mn'],
          ['ffa','s@sgd',123,'mn'],
          ['bdff','s@sgd',123,'mn'],
          ['fc','s@sgd',123,'mn'],
          ['dbd','s@sgd',123,'mn'],
          ['sbg','s@sgd',123,'mn'],
          ['adf','s@sgd',123,'mn'],
          ['fdfb','s@sgd',123,'mn'],
          ['cfb','s@sgd',123,'mn'],
          ['dfb','s@sgd',123,'mn'],
          ['sba','s@sgd',123,'mn'],
          ['bfa','s@sgd',123,'mn'],
          ['fbb','s@sgd',123,'mn'],
          ['cab','s@sgd',123,'mn'],
          ['ba','s@sgd',123,'mn'],
          ['sfb','s@sgd',123,'mn'],
          ['fa','s@sgd',123,'mn'],
          ['bf','s@sgd',123,'mn'],
          ['cw','s@sgd',123,'mn'],
          ['dww','s@sgd',123,'mn'],
          ['sww','s@sgd',123,'mn'],
          ['aww','s@sgd',123,'mn'],
          ['bwwww','s@sgd',123,'mn'],
          ['ddc','s@sgd',123,'mn'],
          ['ddd','s@sgd',123,'mn'],
          ['ddds','s@sgd',123,'mn'],
          ['add','s@sgd',123,'mn'],
          ['bvv','s@sgd',123,'mn'],
          ['vvc','s@sgd',123,'mn'],
          ['ddddd','s@sgd',123,'mn'],
          ['sd','s@sgd',123,'mn'],
          ['avv','s@sgd',123,'mn'],
          ['bbv','s@sgd',123,'mn'],
          ['vc','s@sgd',123,'mn'],
          ['fd','s@sgd',123,'mn'],
          ['sk','s@sgd',123,'mn'],
          ['al','s@sgd',123,'mn'],
          ['gb','s@sgd',123,'mn'],
          ['cng','s@sgd',123,'mn'],
          ['dnn','s@sgd',123,'mn'],
          ['sngz','s@sgd',123,'mn'],
          ['nza','s@sgd',123,'mn'],
          ['bgn','s@sgd',123,'mn'],
          ['gnc','s@sgd',123,'mn'],
          ['aqttr','s@sgd',123,'mn'],
          ['tqb','s@sgd',123,'mn'],
          ['tqtc','s@sgd',123,'mn'],
          ['dtqt','s@sgd',123,'mn'],
          ['rts','s@sgd',123,'mn'],
          ['rtya','s@sgd',123,'mn'],
          ['tyab','s@sgd',123,'mn'],
          ['c','s@sgd',123,'mn'],
          ['adgd','s@sgd',123,'mn'],]

# %%
with open('data.csv','w') as f:
    writer = csv.writer(f)
    
    for i in data :
         writer.writerow(i)

# %%
with open('data.csv','r') as f:
    read_data =csv.reader(f)
    
    for i in read_data:
        print(f.read())
# Out:
# s,s@sgd,123,mn
# a,s@sgd,123,mn
# b,s@sgd,123,mn
# c,s@sgd,123,mn
# d,s@sgd,123,mn
# e,s@sgd,123,mn
# f,s@sgd,123,mn
# bh,s@sgd,123,mn
# c,s@sgd,123,mn
# dx,s@sgd,123,mn
# xs,s@sgd,22,mn
# a d,s@sgd,123,mn
# bd,s@sgd,123,mn
# cc,s@sgd,123,mn
# dd ,s@sgd,123,mn
# sf,s@sgd,123,mn
# fva,s@sgd,123,mn
# bf,s@sgd,123,mn
# cf,s@sgd,123,mn
# fbd,s@sgd,123,mn
# sfb,s@sgd,123,mn
# fa,s@sgd,123,mn
# fb,s@sgd,123,mn
# cab,s@sgd,123,mn
# fd,s@sgd,123,mn
# ffs,s@sgd,123,mn
# ffa,s@sgd,123,mn
# bdff,s@sgd,123,mn
# fc,s@sgd,123,mn
# dbd,s@sgd,123,mn
# sbg,s@sgd,123,mn
# adf,s@sgd,123,mn
# fdfb,s@sgd,123,mn
# cfb,s@sgd,123,mn
# dfb,s@sgd,123,mn
# sba,s@sgd,123,mn
# bfa,s@sgd,123,mn
# fbb,s@sgd,123,mn
# cab,s@sgd,123,mn
# ba,s@sgd,123,mn
# sfb,s@sgd,123,mn
# fa,s@sgd,123,mn
# bf,s@sgd,123,mn
# cw,s@sgd,123,mn
# dww,s@sgd,123,mn
# sww,s@sgd,123,mn
# aww,s@sgd,123,mn
# bwwww,s@sgd,123,mn
# ddc,s@sgd,123,mn
# ddd,s@sgd,123,mn
# ddds,s@sgd,123,mn
# add,s@sgd,123,mn
# bvv,s@sgd,123,mn
# vvc,s@sgd,123,mn
# ...

# %%
with open('test4.bin','wb') as f:
    f.write(b"\x01\x02\x03\x3456789")

# %%
with open('test4.bin','rb') as f:
    print(f.read())
# Out:
# b'\x01\x02\x03456789'

# %%
import csv

# %%
da =[['Id','name','Age','Gender'],
    [4,'Alice',25,'Female'],
    [8,'Bob',30,'Male'],
    [15,'Claire','27','Female'],
    [16,'sudh','24','male'],
    [23,'rohri',21,'male'],
    [42,'sartaj',22,'male'],
    [30,'shivs',23,'male'],
    [45,'raghunath',40,'male'],
    [56,'Ahilya',39,'Female'],
    [60,'bhai',20,'male' ],
    ]

# %%
with open('da.csv','w') as f:
    writer = csv.writer(f)
    
    for i in da :
         writer.writerow(i)

# %%
with open('da.csv','r') as f:
    read_da =csv.reader(f)
    
    for i in read_da:
        print(f.read())
# Out:
# 4,Alice,25,Female
# 8,Bob,30,Male
# 15,Claire,27,Female
# 16,sudh,24,male
# 23,rohri,21,male
# 42,sartaj,22,male
# 30,shivs,23,male
# 45,raghunath,40,male
# 56,Ahilya,39,Female
# 60,bhai,20,male
