# %%
import pandas as pd

# %%
pd.read_csv('plear.csv')
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
 da=pd.read_csv('plear.csv')

# %%
da.columns
# Out:
# Index(['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'],
#       dtype='object')

# %%
da.head()
# Out:
#    Unnamed: 0 Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0           0  1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1           1  2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2           2  3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3           3  4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4           4  5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
#
#     FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  .595  146  327  473   82  37  41   84  151   664
# 1  .543  349  411  760  256  65  60  115  153   528
# 2  .753  137  427  564  190  80  44  148  171  1068
# 3  .625   33   54   87   21   6  10   16   36   132
# 4  .873   73  185  258   42  14  47   44   78   607
#
# [5 rows x 31 columns]

# %%
da.drop('Pos',axis = 1)
# Out:
#      Unnamed: 0   Rk             Player Age   Tm   G  GS    MP   FG   FGA  \
# 0             0    1   Precious Achiuwa  22  TOR  73  28  1725  265   603
# 1             1    2       Steven Adams  28  MEM  76  75  1999  210   384
# 2             2    3        Bam Adebayo  24  MIA  56  56  1825  406   729
# 3             3    4       Santi Aldama  21  MEM  32   0   360   53   132
# 4             4    5  LaMarcus Aldridge  36  BRK  47  12  1050  252   458
# ..          ...  ...                ...  ..  ...  ..  ..   ...  ...   ...
# 837         837  601     Thaddeus Young  33  TOR  26   0   475   67   144
# 838         838  602         Trae Young  23  ATL  76  76  2652  711  1544
# 839         839  603     Omer Yurtseven  23  MIA  56  12   706  130   247
# 840         840  604        Cody Zeller  29  POR  27   0   355   51    90
# 841         841  605        Ivica Zubac  24  LAC  76  76  1852  310   495
#
#      ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.drop(3)
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   Tm   G  GS    MP  \
# 0             0    1          Precious Achiuwa   C  22  TOR  73  28  1725
# 1             1    2              Steven Adams   C  28  MEM  76  75  1999
# 2             2    3               Bam Adebayo   C  24  MIA  56  56  1825
# 4             4    5         LaMarcus Aldridge   C  36  BRK  47  12  1050
# 5             5    6  Nickeil Alexander-Walker  SG  23  TOT  65  21  1466
# ..          ...  ...                       ...  ..  ..  ...  ..  ..   ...
# 837         837  601            Thaddeus Young  PF  33  TOR  26   0   475
# 838         838  602                Trae Young  PG  23  ATL  76  76  2652
# 839         839  603            Omer Yurtseven   C  23  MIA  56  12   706
# 840         840  604               Cody Zeller   C  29  POR  27   0   355
# 841         841  605               Ivica Zubac   C  24  LAC  76  76  1852
#
#       FG  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.drop(3,inplace = True)

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   Tm   G  GS    MP  \
# 0             0    1          Precious Achiuwa   C  22  TOR  73  28  1725
# 1             1    2              Steven Adams   C  28  MEM  76  75  1999
# 2             2    3               Bam Adebayo   C  24  MIA  56  56  1825
# 4             4    5         LaMarcus Aldridge   C  36  BRK  47  12  1050
# 5             5    6  Nickeil Alexander-Walker  SG  23  TOT  65  21  1466
# ..          ...  ...                       ...  ..  ..  ...  ..  ..   ...
# 837         837  601            Thaddeus Young  PF  33  TOR  26   0   475
# 838         838  602                Trae Young  PG  23  ATL  76  76  2652
# 839         839  603            Omer Yurtseven   C  23  MIA  56  12   706
# 840         840  604               Cody Zeller   C  29  POR  27   0   355
# 841         841  605               Ivica Zubac   C  24  LAC  76  76  1852
#
#       FG  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.set_index('Tm')
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
# LAC         841  605               Ivica Zubac   C  24  76  76  1852  310
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.set_index('Tm',inplace = True)

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
# LAC         841  605               Ivica Zubac   C  24  76  76  1852  310
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.reset_index()
# Out:
#       Tm  Unnamed: 0   Rk                    Player Pos Age   G  GS    MP  \
# 0    TOR           0    1          Precious Achiuwa   C  22  73  28  1725
# 1    MEM           1    2              Steven Adams   C  28  76  75  1999
# 2    MIA           2    3               Bam Adebayo   C  24  56  56  1825
# 3    BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050
# 4    TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466
# ..   ...         ...  ...                       ...  ..  ..  ..  ..   ...
# 836  TOR         837  601            Thaddeus Young  PF  33  26   0   475
# 837  ATL         838  602                Trae Young  PG  23  76  76  2652
# 838  MIA         839  603            Omer Yurtseven   C  23  56  12   706
# 839  POR         840  604               Cody Zeller   C  29  27   0   355
# 840  LAC         841  605               Ivica Zubac   C  24  76  76  1852
#
#       FG  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
d= {'key1':[1,2,3,4,5],
    'key2':[5,6,7,8,9],
    'key3':[2,3,5,6,7],




}

# %%
aa =pd.DataFrame(d)

# %%
aa
# Out:
#    key1  key2  key3
# 0     1     5     2
# 1     2     6     3
# 2     3     7     5
# 3     4     8     6
# 4     5     9     7

# %%
aa.to_csv('key.csv')

# %%
p=pd.DataFrame(d)

# %%
p['key1']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: key1, dtype: int64

# %%
p['key2']
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# Name: key2, dtype: int64

# %%
p = ['key1']+['key2']

# %%
p
# Out:
# ['key1', 'key2']

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
# LAC         841  605               Ivica Zubac   C  24  76  76  1852  310
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
# LAC         841  605               Ivica Zubac   C  24  76  76  1852  310
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.dropna()
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.dropna(inplace = True)

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da.dropna(axis= 1)
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
pd.read_csv('plear.csv')
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 
player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
import pandas as pd

# %%
pd.read_csv('plear.csv')
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
daa = pd.read_csv('plear.csv')

# %%
daa['Age']
# Out:
# 0      22
# 1      28
# 2      24
# 3      21
# 4      36
#        ..
# 837    33
# 838    23
# 839    23
# 840    29
# 841    24
# Name: Age, Length: 842, dtype: object

# %%
g = daa.groupby('Age')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_91/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#      Unnamed: 0
# Age
# 19         6346
# 20        12429
# 21        20159
# 22        29953
# 23        34557
# 24        44887
# 25        28973
# 26        27446
# 27        25138
# 28        24533
# 29        18934
# 30        16622
# 31        14495
# 32        11852
# 33        10848
# 34         2645
# 35         6319
# 36         3592
# 37          398
# 38          366
# 40          396
# 41          309
# Age       12864

# %%
g.sum()
# Out:
# /tmp/ipykernel_91/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#      Unnamed: 0
# Age
# 19         6346
# 20        12429
# 21        20159
# 22        29953
# 23        34557
# 24        44887
# 25        28973
# 26        27446
# 27        25138
# 28        24533
# 29        18934
# 30        16622
# 31        14495
# 32        11852
# 33        10848
# 34         2645
# 35         6319
# 36         3592
# 37          398
# 38          366
# 40          396
# 41          309
# Age       12864

# %%
g = daa.groupby('Pos')

# %%
g.sum()
# Out:
# /tmp/ipykernel_91/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Unnamed: 0
# Pos
# C              54353
# C-PF             564
# PF             66116
# PF-SF            341
# PG             68369
# PG-SG            723
# Pos            12864
# SF             59580
# SF-SG           1743
# SG             86256
# SG-PG           1556
# SG-PG-SF         675
# SG-SF            921

# %%
g.mean()
# Out:
# /tmp/ipykernel_91/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           Unnamed: 0
# Pos
# C         388.235714
# C-PF      564.000000
# PF        440.773333
# PF-SF     341.000000
# PG        446.856209
# PG-SG     723.000000
# Pos       428.800000
# SF        389.411765
# SF-SG     435.750000
# SG        429.134328
# SG-PG     389.000000
# SG-PG-SF  675.000000
# SG-SF     307.000000

# %%
g1 = daa.groupby('G')

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_91/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#     Unnamed: 0
# G
# 1        15201
# 10        3982
# 11        3779
# 12        4864
# 13        4500
# ..         ...
# 80         620
# 81        1443
# 82        1263
# 9         8155
# G        12864
#
# [83 rows x 1 columns]

# %%
g1.mean()
# Out:
# /tmp/ipykernel_91/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#     Unnamed: 0
# G
# 1   460.636364
# 10  442.444444
# 11  539.857143
# 12  540.444444
# 13  321.428571
# ..         ...
# 80  155.000000
# 81  360.750000
# 82  252.600000
# 9   543.666667
# G   428.800000
#
# [83 rows x 1 columns]

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_91/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# G                        1           10          11         12             13  \
# Unnamed: 0             831          693         824        827            702
# Rk                      99          502         593        596             70
# Player      Zylan Cheatham  Xavier Moon  Tacko Fall  Yves Pons  Udonis Haslem
# Pos                     SG           SG          SG         SG             SG
# Age                     40           31          26         31             41
# Tm                     WAS          TOT         TOT        WAS            TOT
# GS                       1            3          11          3              6
# MP                       9           98          85         85             83
# ...

# %%
daa
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
daa[['Player','Age','Pos','G']]
# Out:
#                 Player Age Pos   G
# 0     Precious Achiuwa  22   C  73
# 1         Steven Adams  28   C  76
# 2          Bam Adebayo  24   C  56
# 3         Santi Aldama  21  PF  32
# 4    LaMarcus Aldridge  36   C  47
# ..                 ...  ..  ..  ..
# 837     Thaddeus Young  33  PF  26
# 838         Trae Young  23  PG  76
# 839     Omer Yurtseven  23   C  56
# 840        Cody Zeller  29   C  27
# 841        Ivica Zubac  24   C  76
#
# [842 rows x 4 columns]

# %%
daaa =daa[['Player','Age','Pos','G']][0:5]

# %%
daaaa =daa[['Player','Age','Pos','G']][5:10]

# %%
daaa
# Out:
#               Player Age Pos   G
# 0   Precious Achiuwa  22   C  73
# 1       Steven Adams  28   C  76
# 2        Bam Adebayo  24   C  56
# 3       Santi Aldama  21  PF  32
# 4  LaMarcus Aldridge  36   C  47

# %%
daaaa
# Out:
#                      Player Age Pos   G
# 5  Nickeil Alexander-Walker  23  SG  65
# 6  Nickeil Alexander-Walker  23  SG  50
# 7  Nickeil Alexander-Walker  23  SG  15
# 8             Grayson Allen  26  SG  66
# 9             Jarrett Allen  23   C  56

# %%
pd.concat([daaa,daaaa])
# Out:
#                      Player Age Pos   G
# 0          Precious Achiuwa  22   C  73
# 1              Steven Adams  28   C  76
# 2               Bam Adebayo  24   C  56
# 3              Santi Aldama  21  PF  32
# 4         LaMarcus Aldridge  36   C  47
# 5  Nickeil Alexander-Walker  23  SG  65
# 6  Nickeil Alexander-Walker  23  SG  50
# 7  Nickeil Alexander-Walker  23  SG  15
# 8             Grayson Allen  26  SG  66
# 9             Jarrett Allen  23   C  56

# %%
q =pd.concat([daaa,daaaa], axis = 1)

# %%
q.fillna('sudhir')
# Out:
#               Player     Age     Pos       G                    Player  \
# 0   Precious Achiuwa      22       C      73                    sudhir
# 1       Steven Adams      28       C      76                    sudhir
# 2        Bam Adebayo      24       C      56                    sudhir
# 3       Santi Aldama      21      PF      32                    sudhir
# 4  LaMarcus Aldridge      36       C      47                    sudhir
# 5             sudhir  sudhir  sudhir  sudhir  Nickeil Alexander-Walker
# 6             sudhir  sudhir  sudhir  sudhir  Nickeil Alexander-Walker
# 7             sudhir  sudhir  sudhir  sudhir  Nickeil Alexander-Walker
# 8             sudhir  sudhir  sudhir  sudhir             Grayson Allen
# 9             sudhir  sudhir  sudhir  sudhir             Jarrett Allen
#
#       Age     Pos       G
# 0  sudhir  sudhir  sudhir
# 1  sudhir  sudhir  sudhir
# 2  sudhir  sudhir  sudhir
# 3  sudhir  sudhir  sudhir
# 4  sudhir  sudhir  sudhir
# ...

# %%
data1= pd.DataFrame({'key1':[2,3,5,7,3,4],
                     'key2':[11,4,2,4,3,1],
                     'key3':[11,2,3,4,5,6],
                     'key4':[6,5,4,3,2,1],
})

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     2    11    11     6
# 1     3     4     2     5
# 2     5     2     3     4
# 3     7     4     4     3
# 4     3     3     5     2
# 5     4     1     6     1

# %%
data2= pd.DataFrame({'key7': [4,8,1,9,3,4,],
                     'key1':[11,4,2,1,3,1],
                     'key5':[11,2,3,4,9,6],
                     'key8':[11,2,4,3,2,19],
})

# %%
data2
# Out:
#    key7  key1  key5  key8
# 0     4    11    11    11
# 1     8     4     2     2
# 2     1     2     3     4
# 3     9     1     4     3
# 4     3     3     9     2
# 5     4     1     6    19

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key7  key5  key8
# 0     2    11    11     6     1     3     4
# 1     3     4     2     5     3     9     2
# 2     3     3     5     2     3     9     2
# 3     4     1     6     1     8     2     2

# %%
pd.merge(data1,data2, how = 'left')
# Out:
#    key1  key2  key3  key4  key7  key5  key8
# 0     2    11    11     6   1.0   3.0   4.0
# 1     3     4     2     5   3.0   9.0   2.0
# 2     5     2     3     4   NaN   NaN   NaN
# 3     7     4     4     3   NaN   NaN   NaN
# 4     3     3     5     2   3.0   9.0   2.0
# 5     4     1     6     1   8.0   2.0   2.0

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     2    11    11     6
# 1     3     4     2     5
# 2     5     2     3     4
# 3     7     4     4     3
# 4     3     3     5     2
# 5     4     1     6     1

# %%
pd.merge(data1,data2, how = 'right')
# Out:
#    key1  key2  key3  key4  key7  key5  key8
# 0    11   NaN   NaN   NaN     4    11    11
# 1     4   1.0   6.0   1.0     8     2     2
# 2     2  11.0  11.0   6.0     1     3     4
# 3     1   NaN   NaN   NaN     9     4     3
# 4     3   4.0   2.0   5.0     3     9     2
# 5     3   3.0   5.0   2.0     3     9     2
# 6     1   NaN   NaN   NaN     4     6    19

# %%
pd.merge(data1,data2, how = 'outer')
# Out:
#    key1  key2  key3  key4  key7  key5  key8
# 0     2  11.0  11.0   6.0   1.0   3.0   4.0
# 1     3   4.0   2.0   5.0   3.0   9.0   2.0
# 2     3   3.0   5.0   2.0   3.0   9.0   2.0
# 3     5   2.0   3.0   4.0   NaN   NaN   NaN
# 4     7   4.0   4.0   3.0   NaN   NaN   NaN
# 5     4   1.0   6.0   1.0   8.0   2.0   2.0
# 6    11   NaN   NaN   NaN   4.0  11.0  11.0
# 7     1   NaN   NaN   NaN   9.0   4.0   3.0
# 8     1   NaN   NaN   NaN   4.0   6.0  19.0

# %%
pd.merge(data1,data2, how = 'cross')
# Out:
#     key1_x  key2  key3  key4  key7  key1_y  key5  key8
# 0        2    11    11     6     4      11    11    11
# 1        2    11    11     6     8       4     2     2
# 2        2    11    11     6     1       2     3     4
# 3        2    11    11     6     9       1     4     3
# 4        2    11    11     6     3       3     9     2
# 5        2    11    11     6     4       1     6    19
# 6        3     4     2     5     4      11    11    11
# 7        3     4     2     5     8       4     2     2
# 8        3     4     2     5     1       2     3     4
# 9        3     4     2     5     9       1     4     3
# 10       3     4     2     5     3       3     9     2
# 11       3     4     2     5     4       1     6    19
# 12       5     2     3     4     4      11    11    11
# 13       5     2     3     4     8       4     2     2
# 14       5     2     3     4     1       2     3     4
# 15       5     2     3     4     9       1     4     3
# ...

# %%
data1
# Out:
#    key1  key2  key3  key4
# 0     2    11    11     6
# 1     3     4     2     5
# 2     5     2     3     4
# 3     7     4     4     3
# 4     3     3     5     2
# 5     4     1     6     1

# %%
data1= pd.DataFrame({'key1':[2,3,5,7,3,4],
                     'key2':[11,4,2,4,3,1],
                     'key3':[11,2,3,4,5,6],
                     'key4':[6,5,4,3,2,1]},
          index = ['a','b','c','d','e','f'] 
                   )

# %%
data2= pd.DataFrame({'key7':[4,8,1,9,3,4,],
                     'key6':[11,4,2,1,3,1],
                     'key5':[11,2,3,4,9,6],
                     'key8':[11,2,4,3,2,19]},
                  index = ['a','b','h','i','j','k']  
                   )

# %%
data1
# Out:
#    key1  key2  key3  key4
# a     2    11    11     6
# b     3     4     2     5
# c     5     2     3     4
# d     7     4     4     3
# e     3     3     5     2
# f     4     1     6     1

# %%
data2
# Out:
#    key7  key6  key5  key8
# a     4    11    11    11
# b     8     4     2     2
# h     1     2     3     4
# i     9     1     4     3
# j     3     3     9     2
# k     4     1     6    19

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key4  key7  key6  key5  key8
# a     2    11    11     6   4.0  11.0  11.0  11.0
# b     3     4     2     5   8.0   4.0   2.0   2.0
# c     5     2     3     4   NaN   NaN   NaN   NaN
# d     7     4     4     3   NaN   NaN   NaN   NaN
# e     3     3     5     2   NaN   NaN   NaN   NaN
# f     4     1     6     1   NaN   NaN   NaN   NaN

# %%
data1.join(data2,how ='left')
# Out:
#    key1  key2  key3  key4  key7  key6  key5  key8
# a     2    11    11     6   4.0  11.0  11.0  11.0
# b     3     4     2     5   8.0   4.0   2.0   2.0
# c     5     2     3     4   NaN   NaN   NaN   NaN
# d     7     4     4     3   NaN   NaN   NaN   NaN
# e     3     3     5     2   NaN   NaN   NaN   NaN
# f     4     1     6     1   NaN   NaN   NaN   NaN

# %%
data1.join(data2,how ='right')
# Out:
#    key1  key2  key3  key4  key7  key6  key5  key8
# a   2.0  11.0  11.0   6.0     4    11    11    11
# b   3.0   4.0   2.0   5.0     8     4     2     2
# h   NaN   NaN   NaN   NaN     1     2     3     4
# i   NaN   NaN   NaN   NaN     9     1     4     3
# j   NaN   NaN   NaN   NaN     3     3     9     2
# k   NaN   NaN   NaN   NaN     4     1     6    19

# %%
data1.join(data2,how ='inner')
# Out:
#    key1  key2  key3  key4  key7  key6  key5  key8
# a     2    11    11     6     4    11    11    11
# b     3     4     2     5     8     4     2     2

# %%
data1.join(data2,how = 'outer')
# Out:
#    key1  key2  key3  key4  key7  key6  key5  key8
# a   2.0  11.0  11.0   6.0   4.0  11.0  11.0  11.0
# b   3.0   4.0   2.0   5.0   8.0   4.0   2.0   2.0
# c   5.0   2.0   3.0   4.0   NaN   NaN   NaN   NaN
# d   7.0   4.0   4.0   3.0   NaN   NaN   NaN   NaN
# e   3.0   3.0   5.0   2.0   NaN   NaN   NaN   NaN
# f   4.0   1.0   6.0   1.0   NaN   NaN   NaN   NaN
# h   NaN   NaN   NaN   NaN   1.0   2.0   3.0   4.0
# i   NaN   NaN   NaN   NaN   9.0   1.0   4.0   3.0
# j   NaN   NaN   NaN   NaN   3.0   3.0   9.0   2.0
# k   NaN   NaN   NaN   NaN   4.0   1.0   6.0  19.0

# %%
data1.join(data2,how = 'cross')
# Out:
#     key1  key2  key3  key4  key7  key6  key5  key8
# 0      2    11    11     6     4    11    11    11
# 1      2    11    11     6     8     4     2     2
# 2      2    11    11     6     1     2     3     4
# 3      2    11    11     6     9     1     4     3
# 4      2    11    11     6     3     3     9     2
# 5      2    11    11     6     4     1     6    19
# 6      3     4     2     5     4    11    11    11
# 7      3     4     2     5     8     4     2     2
# 8      3     4     2     5     1     2     3     4
# 9      3     4     2     5     9     1     4     3
# 10     3     4     2     5     3     3     9     2
# 11     3     4     2     5     4     1     6    19
# 12     5     2     3     4     4    11    11    11
# 13     5     2     3     4     8     4     2     2
# 14     5     2     3     4     1     2     3     4
# 15     5     2     3     4     9     1     4     3
# 16     5     2     3     4     3     3     9     2
# ...

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# ...

# %%
da['Dowler_INR'] = da['PTS'].apply(lambda x:x*72)

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS  \
# ...

# %%
def data_inr(x):
    return x*72
da['new dowler'] = da ['PTS'].apply(data_inr)

# %%
da
# Out:
#      Unnamed: 0   Rk                    Player Pos Age   G  GS    MP   FG  \
# Tm
# TOR           0    1          Precious Achiuwa   C  22  73  28  1725  265
# MEM           1    2              Steven Adams   C  28  76  75  1999  210
# MIA           2    3               Bam Adebayo   C  24  56  56  1825  406
# BRK           4    5         LaMarcus Aldridge   C  36  47  12  1050  252
# TOT           5    6  Nickeil Alexander-Walker  SG  23  65  21  1466  253
# ..          ...  ...                       ...  ..  ..  ..  ..   ...  ...
# SAS         836  601            Thaddeus Young  PF  33  26   1   370   74
# TOR         837  601            Thaddeus Young  PF  33  26   0   475   67
# ATL         838  602                Trae Young  PG  23  76  76  2652  711
# MIA         839  603            Omer Yurtseven   C  23  56  12   706  130
# POR         840  604               Cody Zeller   C  29  27   0   355   51
#
#       FGA  ...  DRB  TRB  AST STL BLK  TOV   PF   PTS  \
# Tm         ...
# ...

# %%
da.head()
# Out:
#      Unnamed: 0 Rk                    Player Pos Age   G  GS    MP   FG  FGA  \
# Tm
# TOR           0  1          Precious Achiuwa   C  22  73  28  1725  265  603
# MEM           1  2              Steven Adams   C  28  76  75  1999  210  384
# MIA           2  3               Bam Adebayo   C  24  56  56  1825  406  729
# BRK           4  5         LaMarcus Aldridge   C  36  47  12  1050  252  458
# TOT           5  6  Nickeil Alexander-Walker  SG  23  65  21  1466  253  680
#
#      ...  DRB  TRB  AST STL BLK  TOV   PF   PTS  \
player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
ds['player_new'] = ds ['Player'].apply(len)

# %%
ds
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
def cat_fare(x) :
    if x<10:
        return 'new_childrin'
    elif x>=10 and x<15:
        return 'youn'
    else :
        return 'old'

# %%
ds['new_Age'] = ds['player_new'].apply(cat_fare)

# %%
ds
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
ds.tail()
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
#
# Precious Achiuwa          ...  .595  146  327  473   82  37  41   84  151
# Steven Adams              ...  .543  349  411  760  256  65  60  115  153
# Bam Adebayo               ...  .753  137  427  564  190  80  44  148  171
# LaMarcus Aldridge         ...  .873   73  185  258   42  14  47   44   78
# Nickeil Alexander-Walker  ...  .743   37  150  187  156  46  23   93  103
#
# ...

# %%
import pandas as pd

# %%
pd.read_csv('plear.csv')
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
 n=pd.read_csv('plear.csv')

# %%
n
# Out:
#      Unnamed: 0   Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1             1    2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2             2    3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3             3    4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4             4    5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
# ..          ...  ...                ...  ..  ..  ...  ..  ..   ...  ...  ...
# 837         837  601     Thaddeus Young  PF  33  TOR  26   0   475   67  ...
# 838         838  602         Trae Young  PG  23  ATL  76  76  2652  711  ...
# 839         839  603     Omer Yurtseven   C  23  MIA  56  12   706  130  ...
# 840         840  604        Cody Zeller   C  29  POR  27   0   355   51  ...
# 841         841  605        Ivica Zubac   C  24  LAC  76  76  1852  310  ...
#
# ...

# %%
g=n.groupby('G')

# %%
g.sum()
# Out:
# /tmp/ipykernel_98/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#     Unnamed: 0
# G
# 1        15201
# 10        3982
# 11        3779
# 12        4864
# 13        4500
# ..         ...
# 80         620
# 81        1443
# 82        1263
# 9         8155
# G        12864
#
# [83 rows x 1 columns]

# %%
g.max().transpose()
# Out:
# /tmp/ipykernel_98/2848969155.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max().transpose()
# G                        1           10          11         12             13  \
# Unnamed: 0             831          693         824        827            702
# Rk                      99          502         593        596             70
# Player      Zylan Cheatham  Xavier Moon  Tacko Fall  Yves Pons  Udonis Haslem
# Pos                     SG           SG          SG         SG             SG
# Age                     40           31          26         31             41
# Tm                     WAS          TOT         TOT        WAS            TOT
# GS                       1            3          11          3              6
# MP                       9           98          85         85             83
# ...

# %%
n[0:5]
# Out:
#    Unnamed: 0 Rk             Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0           0  1   Precious Achiuwa   C  22  TOR  73  28  1725  265  ...
# 1           1  2       Steven Adams   C  28  MEM  76  75  1999  210  ...
# 2           2  3        Bam Adebayo   C  24  MIA  56  56  1825  406  ...
# 3           3  4       Santi Aldama  PF  21  MEM  32   0   360   53  ...
# 4           4  5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  ...
#
#     FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  .595  146  327  473   82  37  41   84  151   664
# 1  .543  349  411  760  256  65  60  115  153   528
# 2  .753  137  427  564  190  80  44  148  171  1068
# 3  .625   33   54   87   21   6  10   16   36   132
# 4  .873   73  185  258   42  14  47   44   78   607
#
# [5 rows x 31 columns]

# %%
ds= n[0:5]

# %%
n[5:10]
# Out:
#    Unnamed: 0 Rk                    Player Pos Age   Tm   G  GS    MP   FG  \
# 5           5  6  Nickeil Alexander-Walker  SG  23  TOT  65  21  1466  253
# 6           6  6  Nickeil Alexander-Walker  SG  23  NOP  50  19  1317  237
# 7           7  6  Nickeil Alexander-Walker  SG  23  UTA  15   2   149   16
# 8           8  7             Grayson Allen  SG  26  MIL  66  61  1805  255
# 9           9  8             Jarrett Allen   C  23  CLE  56  56  1809  369
#
#    ...   FT%  ORB  DRB  TRB  AST STL BLK TOV   PF  PTS
# 5  ...  .743   37  150  187  156  46  23  93  103  692
# 6  ...  .722   36  128  164  139  41  19  85   88  639
# 7  ...  .917    1   22   23   17   5   4   8   15   53
# 8  ...  .865   32  190  222  100  46  18  43   96  733
# 9  ...  .708  192  410  602   92  44  75  94   97  904
#
# [5 rows x 31 columns]

# %%
 dss=n[5:10]

# %%
ds= n[0:5]

# %%
pd.concat([ds,dss] )
# Out:
#    Unnamed: 0 Rk                    Player Pos Age   Tm   G  GS    MP   FG  \
# 0           0  1          Precious Achiuwa   C  22  TOR  73  28  1725  265
# 1           1  2              Steven Adams   C  28  MEM  76  75  1999  210
# 2           2  3               Bam Adebayo   C  24  MIA  56  56  1825  406
# 3           3  4              Santi Aldama  PF  21  MEM  32   0   360   53
# 4           4  5         LaMarcus Aldridge   C  36  BRK  47  12  1050  252
# 5           5  6  Nickeil Alexander-Walker  SG  23  TOT  65  21  1466  253
# 6           6  6  Nickeil Alexander-Walker  SG  23  NOP  50  19  1317  237
# 7           7  6  Nickeil Alexander-Walker  SG  23  UTA  15   2   149   16
# 8           8  7             Grayson Allen  SG  26  MIL  66  61  1805  255
# 9           9  8             Jarrett Allen   C  23  CLE  56  56  1809  369
#
#    ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  ...  .595  146  327  473   82  37  41   84  151   664
# ...

# %%
 dss=pd.concat([ds,dss], axis = 1)

# %%
dss
# Out:
#    Unnamed: 0   Rk             Player  Pos  Age   Tm    G   GS    MP   FG  \
# 0         0.0    1   Precious Achiuwa    C   22  TOR   73   28  1725  265
# 1         1.0    2       Steven Adams    C   28  MEM   76   75  1999  210
# 2         2.0    3        Bam Adebayo    C   24  MIA   56   56  1825  406
# 3         3.0    4       Santi Aldama   PF   21  MEM   32    0   360   53
# 4         4.0    5  LaMarcus Aldridge    C   36  BRK   47   12  1050  252
# 5         NaN  NaN                NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 6         NaN  NaN                NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 7         NaN  NaN                NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 8         NaN  NaN                NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 9         NaN  NaN                NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
#    ...   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# 0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
data1 = pd.DataFrame({'key1':[1,3,5,7,9],
                      'key2':[2,3,7,9,1],
                     'key3':[4,2,1,6,7],






})

# %%
data2= pd.DataFrame({'key6':[1,3,5,2,9],
                    'key1':[2,4,7,5,1],
                      'key5':[4,2,3,6,7],








})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     2     4
# 1     3     3     2
# 2     5     7     1
# 3     7     9     6
# 4     9     1     7

# %%
data2
# Out:
#    key6  key1  key5
# 0     1     2     4
# 1     3     4     2
# 2     5     7     3
# 3     2     5     6
# 4     9     1     7

# %%
pd.concat([data1,data2])
# Out:
#    key1  key2  key3  key6  key5
# 0     1   2.0   4.0   NaN   NaN
# 1     3   3.0   2.0   NaN   NaN
# 2     5   7.0   1.0   NaN   NaN
# 3     7   9.0   6.0   NaN   NaN
# 4     9   1.0   7.0   NaN   NaN
# 0     2   NaN   NaN   1.0   4.0
# 1     4   NaN   NaN   3.0   2.0
# 2     7   NaN   NaN   5.0   3.0
# 3     5   NaN   NaN   2.0   6.0
# 4     1   NaN   NaN   9.0   7.0

# %%
A =pd.concat([data1,data2])

# %%
import pandas as pd

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key6  key5
# 0     1     2     4     9     7
# 1     5     7     1     2     6
# 2     7     9     6     5     3

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key6  key5
# 0     1     2     4   9.0   7.0
# 1     3     3     2   NaN   NaN
# 2     5     7     1   2.0   6.0
# 3     7     9     6   5.0   3.0
# 4     9     1     7   NaN   NaN

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key6  key5
# 0     2   NaN   NaN     1     4
# 1     4   NaN   NaN     3     2
# 2     7   9.0   6.0     5     3
# 3     5   7.0   1.0     2     6
# 4     1   2.0   4.0     9     7

# %%
pd.merge(data1,data2,how = 'outer')
# Out:
#    key1  key2  key3  key6  key5
# 0     1   2.0   4.0   9.0   7.0
# 1     3   3.0   2.0   NaN   NaN
# 2     5   7.0   1.0   2.0   6.0
# 3     7   9.0   6.0   5.0   3.0
# 4     9   1.0   7.0   NaN   NaN
# 5     2   NaN   NaN   1.0   4.0
# 6     4   NaN   NaN   3.0   2.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key6  key1_y  key5
# 0        1     2     4     1       2     4
# 1        1     2     4     3       4     2
# 2        1     2     4     5       7     3
# 3        1     2     4     2       5     6
# 4        1     2     4     9       1     7
# 5        3     3     2     1       2     4
# 6        3     3     2     3       4     2
# 7        3     3     2     5       7     3
# 8        3     3     2     2       5     6
# 9        3     3     2     9       1     7
# 10       5     7     1     1       2     4
# 11       5     7     1     3       4     2
# 12       5     7     1     5       7     3
# 13       5     7     1     2       5     6
# 14       5     7     1     9       1     7
# 15       7     9     6     1       2     4
# 16       7     9     6     3       4     2
# 17       7     9     6     5       7     3
# 18       7     9     6     2       5     6
# 19       7     9     6     9       1     7
# 20       9     1     7     1       2     4
# ...
